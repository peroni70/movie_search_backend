# %%
import requests
from bs4 import BeautifulSoup
import itertools
import pandas as pd
import operator
import numpy as np
import json

# %%
# this is the primary search url to get movie data
# for experimenting, we will search for 250 movies
url = '''https://www.imdb.com/search/title/?title_type=feature&user_rating=4.0,10.0&num_votes=50000,&view=simple&sort=user_rating,desc&count=250&ref_=adv_prv'''

# %%
r = requests.get(url)

# %%
movie_soup = BeautifulSoup(r.text, 'html.parser')

# %%
def getSoup(link):
    r = requests.get(link)
    movie_soup = BeautifulSoup(r.text, 'html.parser')
    return movie_soup

# %%
def getReviewText(review_url):
    '''Returns the user review text given the review url.'''
    
    # get the review_url's soup
    soup = getSoup(review_url)
    
    # find div tags with class text show-more__control
    tag = soup.find('div', attrs={'class': 'text show-more__control'})
    
    return tag.getText()

# %%
def sampleReviews(user_review_ratings):
    num_reviews = len(user_review_ratings)
    print(num_reviews)
    if num_reviews < 5:
        return list(range(5))
    indices, reviews_sorted = zip(*sorted(enumerate(user_review_ratings), key=operator.itemgetter(1)))
    if num_reviews % 2 == 0:
        median = int(num_reviews / 2)
    else:
        median = int((num_reviews - 1) / 2)
    x = [0, median-1, median, median+1, num_reviews-1]
    return [indices[i] for i in x]

# %%
def getReviews(soup):
    '''Function returns a negative and positive review for each movie.'''
    
    # get a list of user ratings
    user_review_ratings = [tag.previous_element for tag in 
                           soup.find_all('span', attrs={'class': 'point-scale'})]
    
    user_review_ratings = list(map(int, user_review_ratings))
    sample_indices = sampleReviews(user_review_ratings)
    # get the review tags
    user_review_list = soup.find_all('a', attrs={'class':'title'})
    
    
    links = list(map(lambda x: "https://www.imdb.com" + x['href'], user_review_list))
    return [links[i] for i in sample_indices]

# %%
def getDescs(link):
    # get the review_url's soup
    soup = getSoup(link)
    # find div tags with class text summary_text
    tag = soup.find('div', attrs={'class': 'summary_text'})
    return tag.getText()

# %%
def getMovieTitle(review_url):
    '''Returns the movie title from the review url.'''
    
    # get the review_url's soup
    soup = getSoup(review_url)
    
    # find h1 tag
    tag = soup.find('h1')
    
    return list(tag.children)[1].getText()

# %%
# find all a-tags with class:None
movie_tags = movie_soup.find_all('a', attrs={'class': None})

# filter the a-tags to get just the titles
movie_tags = [tag.attrs['href'] for tag in movie_tags 
              if tag.attrs['href'].startswith('/title') & tag.attrs['href'].endswith('/')]

# remove duplicate links
movie_tags = list(dict.fromkeys(movie_tags))

# %%
# movie links
base_url = "https://www.imdb.com"
movie_review_links = [base_url + tag + 'reviews' for tag in movie_tags]
movie_links = [base_url + tag for tag in movie_tags]

# %%
movie_review_links
# Out:
# ['https://www.imdb.com/title/tt0111161/reviews',
#  'https://www.imdb.com/title/tt0068646/reviews',
#  'https://www.imdb.com/title/tt0468569/reviews',
#  'https://www.imdb.com/title/tt0071562/reviews',
#  'https://www.imdb.com/title/tt0050083/reviews',
#  'https://www.imdb.com/title/tt0167260/reviews',
#  'https://www.imdb.com/title/tt0110912/reviews',
#  'https://www.imdb.com/title/tt0108052/reviews',
#  'https://www.imdb.com/title/tt5813916/reviews',
#  'https://www.imdb.com/title/tt1375666/reviews',
#  'https://www.imdb.com/title/tt0077416/reviews',
#  'https://www.imdb.com/title/tt0075148/reviews',
#  'https://www.imdb.com/title/tt0074958/reviews']

# %%
movie_soups = [getSoup(link) for link in movie_review_links]

# %%
movie_descs = [getDescs(link) for link in movie_links]

# %%
movie_review_list = [getReviews(movie_soup) for movie_soup in movie_soups]
movie_review_list = list(itertools.chain(*movie_review_list))
# Out:
# 23
# 24
# 24
# 23
# 20
# 22
# 24
# 18
# 23
# 25
# 22
# 21
# 22
# 21
# 22
# 23
# 20
# 21
# 23
# 24
# 24
# 24
# 21
# 20
# 20
# 23
# 22
# 20
# 20
# 23
# 19
# 23
# 25
# 23
# 22
# 23
# 24
# 23
# 21
# 22
# 19
# 23
# 22
# 25
# 22
# 22
# 20
# 22
# 23
# 20
# 22
# 18
# 24
# 24
# 17
# 23
# 25
# 24
# 24
# 25
# 24
# 25
# 24
# 24
# 21
# 23
# 24
# 19
# 25
# 20
# 24
# 17
# 20
# 21
# 22
# 23
# 20
# 21
# 20
# 21
# 25
# 24
# 22
# 25
# 24
# 23
# 23
# 24
# 20
# 18
# 21
# 19
# 18
# 22
# 23
# 20
# 19
# 19
# 24
# 19
# 21
# 23
# 22
# 21
# 23
# 24
# 21
# 23
# 18
# 21
# 16
# 22
# 20
# 22
# 21
# 23
# 23
# 21
# 25
# 25
# 23
# 24
# 24
# 24
# 23
# 23
# 17
# 24
# 22
# 25
# 23
# 20
# 25
# 23
# 23
# 24
# 23
# 25
# 24
# 21
# 22
# 25
# 24
# 23
# 19
# 19
# 21
# 21
# 25
# 25
# 21
# 24
# 22
# 20
# 19
# 23
# 21
# 22
# 20
# 21
# 17
# 20
# 22
# 21
# 22
# 22
# 20
# 23
# 21
# 18
# 20
# 23
# 20
# 23
# 24
# 24
# 24
# 24
# 23
# 25
# 23
# 24
# 25
# 24
# 25
# 23
# 24
# 24
# 23
# 24
# 24
# 25
# 22
# 25
# 25
# 23
# 23
# 25
# 25
# 25
# 25
# 21
# 20
# 25
# 24
# 25
# 23
# 24
# 18
# 20
# 19
# 23
# 23
# 22
# 20
# 19
# 21
# 21
# 20
# 19
# 20
# 23
# 21
# 21
# 18
# 22
# 19
# 21
# 22
# 22
# 20
# 22
# 21
# 19
# 21
# 19
# 23
# 23
# 23
# 20
# 23
# 21
# 19
# 23
# 20
# 20
# 24
# 22
# 25
# 24

# %%
movie_reviews = [getReviewText(movie_review) for movie_review in movie_review_list]

# %%
movie_reviews
# Out:
# ['If you like hopeful, surprising, never-seen-before characters, you will enjoy this amusing story of a family of prisoners victimized by the system and a Bible thumping pig.Robbins and Freeman, and everybody else, gives perfect performances for their characters. Their actions and body languages are perfect for this story and movie.',
#  'A Wednesday is a movie which took me by shock to think that there are a few "New Wavers" ( a filmmaker that follow a new wave) in the Indian film factory. If i cud i wud personally like to congratulate the the movie squad who is responsible for this utterly contemplative movie, a one of its kind revolution. The best part is it dint need to have the highly hyped stars like amitabh, SRK or Akshay. This movie has a vast potential to create awareness, patriotism, n self realization not just among the common people but also among the people who are responsible for the violence. I still cant stop being amazed at a story so original n real n solemnly portrayed.. just short of words of appreciation towards the makers.. it had the effect of a \' taaare zameen par\' on me.. so to the faculty of the movie my message is even if u dint get phony awards like film-fare and so on..please remember that u have made a mark in the hearts of the people who actually matter n they adore u for that .. GOOD LUCK . CHEERS !!!!!!',
#  ...]

# %%
# get movie name from the review link
movie_titles = [getMovieTitle(url) for url in movie_review_list]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-598-ec6f59d61dbb> in <module>
#       1 # get movie name from the review link
# ----> 2 movie_titles = [getMovieTitle(url) for url in movie_review_list]
#
# <ipython-input-598-ec6f59d61dbb> in <listcomp>(.0)
#       1 # get movie name from the review link
# ----> 2 movie_titles = [getMovieTitle(url) for url in movie_review_list]
#
# <ipython-input-468-fb1fdb7a2758> in getMovieTitle(review_url)
#       3
#       4     # get the review_url's soup
# ----> 5     soup = getSoup(review_url)
#       6
#       7     # find h1 tag
#
# <ipython-input-463-5cf5d6f3c81e> in getSoup(link)
#       1 def getSoup(link):
# ----> 2     r = requests.get(link)
#       3     movie_soup = BeautifulSoup(r.text, 'html.parser')
#       4     return movie_soup
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
# sometimes two movies have the same name!
len(movie_titles)
# Out:
# 1250

# %%
review_df_2 = pd.DataFrame({'movie': movie_titles, 'user_review_permalink': movie_review_list,
             'user_review': movie_reviews})

# %%
review_df_2
# Out:
#                                        movie  \
# 0                               Barry Lyndon
# 1                               Barry Lyndon
# 2                               Barry Lyndon
# 3                               Barry Lyndon
# 4                               Barry Lyndon
# ...                                      ...
# 1245  The Girl with the Dragon Tattoo (2009)
# 1246  The Girl with the Dragon Tattoo (2009)
# 1247  The Girl with the Dragon Tattoo (2009)
# 1248  The Girl with the Dragon Tattoo (2009)
# 1249  The Girl with the Dragon Tattoo (2009)
#
#                        user_review_permalink  \
# 0     https://www.imdb.com/review/rw0140168/
# 1     https://www.imdb.com/review/rw0140181/
# 2     https://www.imdb.com/review/rw1658035/
# 3     https://www.imdb.com/review/rw2055218/
# 4     https://www.imdb.com/review/rw1639677/
# ...                                      ...
# 1245  https://www.imdb.com/review/rw2286855/
# 1246  https://www.imdb.com/review/rw2264644/
# 1247  https://www.imdb.com/review/rw2119206/
# 1248  https://www.imdb.com/review/rw2032029/
# 1249  https://www.imdb.com/review/rw2225421/
#
#                                             user_review           movie_id
# 0     Spoilers herein.Kubrick is a hard filmmaker to...  /title/tt0072684/
# 1     In fact it's one of Kubrick's most gripping pi...  /title/tt0072684/
# 2     The beauty, the depth, and the mystery of this...  /title/tt0072684/
# 3     Some movies - I wish there were more of them -...  /title/tt0072684/
# 4     1. "See the pretty pictures" 2. You can watch ...  /title/tt0072684/
# ...                                                 ...                ...
# 1245  Män som hatar kvinnor (The Girl With a Dragon ...  /title/tt1132620/
# 1246  The Girl with the Dragon Tattoo, or as it is o...  /title/tt1132620/
# 1247  Awesome Swedish film with a intelligent story....  /title/tt1132620/
# 1248  This film was very well-made with superb cinem...  /title/tt1132620/
# 1249  I basically enjoyed this film, as reflected in...  /title/tt1132620/
#
# [1250 rows x 4 columns]

# %%
review_df_2['movie_id'] = list(map(lambda x: movie_df_2[movie_df_2.movie_title == x].movie_id.iloc[0], review_df_2.movie))

# %%
len(review_df_2.movie.unique())
# Out:
# 250

# %%
movie_df_2 = pd.DataFrame({'movie_title': review_df_2.movie.unique(), "movie_id": movie_tags, 'movie_desc': movie_descs})

# %%
movie_df_2['movie_desc'] = movie_df_2['movie_desc'].apply(clean_movie_desc)

# %%
movie_df_2
# Out:
#                                 movie_title           movie_id  \
# 0                              Barry Lyndon  /title/tt0072684/
# 1                                 Chinatown  /title/tt0071315/
# 2                                   Solaris  /title/tt0069293/
# 3                            Cool Hand Luke  /title/tt0061512/
# 4                                   Persona  /title/tt0060827/
# ..                                      ...                ...
# 245                                  Mother  /title/tt1216496/
# 246                              The Chaser  /title/tt1190539/
# 247     The Hobbit: The Desolation of Smaug  /title/tt1170358/
# 248                        The White Ribbon  /title/tt1149362/
# 249  The Girl with the Dragon Tattoo (2009)  /title/tt1132620/
#
#                                             movie_desc
# 0    An Irish rogue wins the heart of a rich widow ...
# 1    A private detective hired to expose an adulter...
# 2    A psychologist is sent to a station orbiting a...
# 3    A laid back Southern man is sentenced to two y...
# 4    A nurse is put in charge of a mute actress and...
# ..                                                 ...
# 245  A mother desperately searches for the killer w...
# 246  A disgraced ex-policeman who runs a small ring...
# 247  The dwarves, along with Bilbo Baggins and Gand...
# 248  Strange events happen in a small village in th...
# 249  A journalist is aided by a young female hacker...
#
# [250 rows x 3 columns]

# %%
movie_df.append(movie_df_2)
# Out:
#                       movie_title           movie_id  \
# 0        The Shawshank Redemption  /title/tt0111161/
# 1                   The Godfather  /title/tt0068646/
# 2                 The Dark Knight  /title/tt0468569/
# 3          The Godfather: Part II  /title/tt0071562/
# 4                    12 Angry Men  /title/tt0050083/
# ..                            ...                ...
# 245              The Elephant Man  /title/tt1216496/
# 246  Monty Python's Life of Brian  /title/tt1190539/
# 247               The Deer Hunter  /title/tt1170358/
# 248                         Rocky  /title/tt1149362/
# 249                       Network  /title/tt1132620/
#
#                                             movie_desc
# 0    Two imprisoned men bond over a number of years...
# 1    An organized crime dynasty's aging patriarch t...
# 2    When the menace known as the Joker wreaks havo...
# 3    The early life and career of Vito Corleone in ...
# 4    A jury holdout attempts to prevent a miscarria...
# ..                                                 ...
# 245  A mother desperately searches for the killer w...
# 246  A disgraced ex-policeman who runs a small ring...
# 247  The dwarves, along with Bilbo Baggins and Gand...
# 248  Strange events happen in a small village in th...
# 249  A journalist is aided by a young female hacker...
#
# [500 rows x 3 columns]

# %%
# construct a dataframe
review_df = pd.DataFrame({'movie': movie_titles, 'user_review_permalink': movie_review_list,
             'user_review': movie_reviews})

# %%
movie_df = pd.DataFrame({'movie': review_df.movie.unique(), "movie_id": movie_tags, 'movie_desc': movie_descs})

# %%
review_df['movie_id'] = list(map(lambda x: movie_df[movie_df.movie == x].movie_id.iloc[0], review_df.movie))

# %%
review_df
# Out:
#                          movie                   user_review_permalink  \
# 0     The Shawshank Redemption  https://www.imdb.com/review/rw5504423/
# 1     The Shawshank Redemption  https://www.imdb.com/review/rw0348302/
# 2     The Shawshank Redemption  https://www.imdb.com/review/rw0348222/
# 3     The Shawshank Redemption  https://www.imdb.com/review/rw4203332/
# 4     The Shawshank Redemption  https://www.imdb.com/review/rw1790341/
# ...                        ...                                     ...
# 1245                   Network  https://www.imdb.com/review/rw0148806/
# 1246                   Network  https://www.imdb.com/review/rw1803766/
# 1247                   Network  https://www.imdb.com/review/rw1724702/
# 1248                   Network  https://www.imdb.com/review/rw1796611/
# 1249                   Network  https://www.imdb.com/review/rw0148816/
#
#                                             user_review           movie_id
# 0     The Shawshank Redemption has great performance...  /title/tt0111161/
# 1     Misery and Stand By Me were the best adaptatio...  /title/tt0111161/
# 2     One of the finest films made in recent years. ...  /title/tt0111161/
# 3     I've lost count of the number of times I have ...  /title/tt0111161/
# 4     One of my favorite movies ever,The Shawshank R...  /title/tt0111161/
# ...                                                 ...                ...
# 1245  Engrossing satire from Paddy Chayefsky and Sid...  /title/tt0074958/
# 1246  To think that this blackest of black comedies ...  /title/tt0074958/
# 1247  "Network" is a fantastic movie that illustrate...  /title/tt0074958/
# 1248  I can't put it more perfectly than Turner Clas...  /title/tt0074958/
# 1249  When this movie came out in '76 I didn't bothe...  /title/tt0074958/
#
# [1250 rows x 4 columns]

# %%
movie_df = movie_df.rename(columns={"movie": "movie_title"})

# %%
movie_df = movie_df.drop(["embedding"], axis=1)

# %%
def clean_movie_desc(desc):
    desc = desc.replace('\n','')
    desc = desc.replace('\t','')
    desc = desc.strip()
    return desc

# %%
movie_df['movie_desc'] = movie_df['movie_desc'].apply(clean_movie_desc)

# %%
movie_df = movie_df.append(movie_df_2)

# %%
review_df = review_df.append(review_df_2)

# %%
review_df['user_review'].index = np.array(list(range(2500)))

# %%
movie_df.index = np.array(list(range(500)))

# %%
import sqlite3

# %%
conn = sqlite3.connect("movie_search.db")

# %%
movie_df.to_sql("movies", conn, if_exists="replace")

# %%
review_df.to_sql("movie_reviews", conn, if_exists="replace")

# %%
movie_df.to_parquet("movies.parquet")

# %%
review_df.to_parquet("reviews.parquet")

# %%
len(movie_df['movie_title'].unique())
# Out:
# 500

# %% [markdown]
# Now onto the word embedding fun
#
# Embed the reviews, put them in a faiss index
#
# add an id to the reviews and have lookup so you can grab a movie title from the search results
#
# or maybe you average the final embeddings of the three (or whatever reviews) and that represents your movie embedding

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer('stsb-distilbert-base')
model.max_seq_length = 512

# %%
embeddings = model.encode(review_df['user_review'])

# %%
def normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
        return v
    return v / norm

# %%
# make embeddings part of dataframe, avg by movie title
avg_embeddings = np.array([sum(embeddings[i:i+5])/5 for i in range(0,len(embeddings),5)])

# %%
unit_embeddings = np.array([normalize(v) for v in avg_embeddings])

# %%
#make sure these are normalized
np.sqrt(np.dot(unit_embeddings[2], unit_embeddings[2]))
# Out:
# 1.0

# %%
embedding_idx_to_movie_id = {idx: iD for idx, iD in enumerate(movie_df.movie_id)}

# %%
with open('embedding_idx_to_movie_id.json', 'w') as f:
    json.dump(embedding_idx_to_movie_id, f)

# %%
np.save('movie_embeddings.npy', unit_embeddings)

# %%
len(unit_embeddings)
# Out:
# 500

# %%
import faiss

# %%
index = faiss.IndexFlatL2(768)

# %%
index.add(avg_embeddings)

# %%
query = model.encode('testing')
query = np.expand_dims(query, axis=0)
# Out:
# [-1.74594328e-01 -1.34325206e-01 -2.54986603e-02  1.54831469e-01
#  -1.41939640e-01 -1.03486490e+00  1.22950876e+00 -2.25556791e-01
#   1.06800318e+00 -1.30085337e+00 -2.42344856e-01 -2.72629827e-01
#   1.25108874e+00 -6.13501489e-01 -7.33723640e-01  1.31042197e-01
#  -3.58030528e-01 -5.04424274e-01  2.53253672e-02 -3.56378049e-01
#   4.11975473e-01 -8.31088305e-01 -1.48069963e-01 -2.72621483e-01
#   3.07531923e-01 -4.10301238e-02  1.13078690e+00  1.13574660e+00
#  -3.41107219e-01  2.61661261e-02 -1.86967447e-01 -1.21625708e-02
#  -2.77172536e-01  8.49388897e-01  4.14975733e-01  1.58170789e-01
#   6.03025496e-01  3.42809826e-01 -8.95459056e-02 -3.14121068e-01
#  -7.07229197e-01 -3.01484138e-01 -1.78608447e-02 -8.44415724e-02
#  -1.17227614e+00  4.30768579e-02 -1.36279690e+00  1.87077746e-01
#  -1.01705682e+00  5.18015444e-01 -2.95079589e-01  7.10242331e-01
#  -3.07246417e-01 -6.17124557e-01 -2.89518982e-01  4.54043776e-01
#  -1.14548683e-01 -2.93364730e-02 -4.61105496e-01  6.80632174e-01
#  -4.96259063e-01 -8.81427750e-02  3.52780260e-02  2.31301427e-01
#   6.05616391e-01  2.00847864e-01  3.90256256e-01 -3.79925340e-01
#   4.20997947e-01 -3.22049469e-01 -1.87853992e-01 -6.42076135e-02
#  -3.13806444e-01 -6.69777393e-01 -2.42286790e-02  3.16494942e-01
#   8.18657219e-01  3.44665080e-01  1.29132366e+00  7.55054235e-01
#  -3.15130115e-01 -9.98487234e-01 -6.51800692e-01 -4.19664413e-01
#   8.43188941e-01 -9.54630375e-01  5.45770109e-01  3.29029441e-01
#  -8.28315020e-01  2.41263762e-01  8.68982136e-01 -4.87952471e-01
#  -6.67836726e-01 -5.69395304e-01  1.66581586e-01 -5.92908859e-01
#   1.91876784e-01  3.04184526e-01  2.19585061e-01  9.15486574e-01
#  -2.79371738e-02 -4.93065029e-01  9.98190343e-02  2.03608632e-01
#   1.26783025e+00  9.83972251e-02  3.02995712e-01 -4.68400747e-01
#  -1.18464696e+00 -2.52067715e-01  8.42861474e-01 -7.06414640e-01
#  -4.04471487e-01  3.30598444e-01 -4.63419676e-01  5.15383661e-01
#  -4.94437456e-01 -1.21309273e-01 -8.57527182e-02  4.23075706e-02
#   1.01879478e+00 -4.55224037e-01  7.60029614e-01 -1.93777010e-01
#   2.64397383e-01  3.30101810e-02 -2.87267894e-01 -3.99230033e-01
#   2.82222658e-01 -9.88050699e-01 -1.05548906e+00 -8.59432459e-01
#  -3.91144872e-01 -6.01717055e-01  5.51748693e-01 -1.75532043e-01
#  -9.55377400e-01 -3.75822306e-01 -7.22957671e-01 -2.44804859e-01
#   6.29089698e-02  3.16420406e-01 -2.12299690e-01  3.06903690e-01
#   9.51407135e-01  6.42249361e-02 -4.39291209e-01 -1.02976966e+00
#   2.82995760e-01 -2.37919167e-01  6.41479075e-01  6.81502044e-01]

# %%
query.shape
# Out:
# (1, 768)

# %%
_, I = index.search(query, 10)

# %%
I = I * 5

# %%
df.loc[I[0]]
# Out:
#                                                   movie  \
# 1090                                     Monsters, Inc.
# 135                                               Se7en
# 1115                             Crna macka, beli macor
# 1245                                            Network
# 265                                               Joker
# 385                                         Rear Window
# 1100                                    The Sixth Sense
# 370   Dr. Strangelove or: How I Learned to Stop Worr...
# 725                 Lock, Stock and Two Smoking Barrels
# 780                                             Stalker
#
#                        user_review_permalink  \
# 1090  https://www.imdb.com/review/rw0954846/
# 135   https://www.imdb.com/review/rw0370669/
# 1115  https://www.imdb.com/review/rw0410207/
# 1245  https://www.imdb.com/review/rw3865843/
# 265   https://www.imdb.com/review/rw5159304/
# 385   https://www.imdb.com/review/rw4130958/
# 1100  https://www.imdb.com/review/rw2359046/
# 370   https://www.imdb.com/review/rw2928529/
# 725   https://www.imdb.com/review/rw0457209/
# 780   https://www.imdb.com/review/rw1194994/
#
#                                             user_review
# 1090  I thought Billy Crystal and John Goodman were ...
# 135   The movie, "Se7en", starring Brad Pitt, Morgan...
# 1115  This is an extremely quirky film, riddled with...
# 1245  I recently rewatched this movie I've seen at l...
# 265   Every once in a while a movie comes, that trul...
# 385   I must say, no signs of aging. Embedded in its...
# 1100  The Sixth Sense enjoys being playful with our ...
# 370   I never really bought into the Kubrick hype. I...
# 725   The first time I saw this movie I had difficul...
# 780   Andrei Tarkovsky is a rarity among filmmakers ...

# %%
I
# Out:
# array([[126, 138, 114, 225, 279,   3, 159, 171, 192, 264]])

# %%
df[df['movie'] == 'Joker']
# Out:
#      movie                   user_review_permalink  \
# 265  Joker  https://www.imdb.com/review/rw5159304/
# 266  Joker  https://www.imdb.com/review/rw5168360/
# 267  Joker  https://www.imdb.com/review/rw5092831/
# 268  Joker  https://www.imdb.com/review/rw5092869/
# 269  Joker  https://www.imdb.com/review/rw5160204/
#
#                                            user_review
# 265  Every once in a while a movie comes, that trul...
# 266  This is a movie that only those who have felt ...
# 267  Truly a masterpiece, The Best Hollywood film o...
# 268  Joaquin Phoenix gives a tour de force performa...
# 269  Most of the time movies are anticipated like t...

# %%
from functools import lru_cache
import time

# %%
@lru_cache(maxsize=None)
def myfun(s, n):
    time.sleep(5)
    return s

# %%
s = myfun("hello", 6)
print(s)
# Out:
# hello
